x86_64.whl (3.5MB)
#      |████████████████████████████████| 3.5MB 25.6MB/s eta 0:00:01:00:01    | 522kB 25.6MB/s eta 0:00:01█████████████████████████▍    | 3.0MB 25.6MB/s eta 0:00:01MB/s eta 0:00:01��███████████████████▊| 3.5MB 25.6MB/s eta 0:00:01
# Collecting resampy==0.2.1 (from turicreate)
#   Downloading https://files.pythonhosted.org/packages/14/b6/66a06d85474190b50aee1a6c09cdc95bb405ac47338b27e9b21409da1760/resampy-0.2.1.tar.gz (322kB)
#      |████████████████████████████████| 327kB 43.1MB/s eta 0:00:01B 43.1MB/s eta 0:00:01| 317kB 43.1MB/s eta 0:00:01
# Requirement already satisfied: decorator>=4.0.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from turicreate) (4.4.0)
# Collecting wrapt>=1.11.1 (from tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Collecting keras-applications>=1.0.8 (from tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 14.5MB/s eta 0:00:01
# Collecting opt-einsum>=2.3.2 (from tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/b8/83/755bd5324777875e9dff19c2e59daec837d0378c09196634524a3d7269ac/opt_einsum-3.1.0.tar.gz (69kB)
#      |████████████████████████████████| 71kB 5.1MB/s eta 0:00:011
# Requirement already satisfied: gast==0.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow>=2.0.0->turicreate) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow>=2.0.0->turicreate) (1.1.0)
# Collecting tensorboard<2.2.0,>=2.1.0 (from tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/40/23/53ffe290341cd0855d595b0a2e7485932f473798af173bbe3a584b99bb06/tensorboard-2.1.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 53kB/s eta 0:00:0101��                              | 235kB 23.9MB/s eta 0:00:01�█▏                           | 501kB 23.9MB/s eta 0:00:01�███▎                       | 993kB 23.9MB/s eta 0:00:01| 1.2MB 23.9MB/s eta 0:00:01��████████                    | 1.4MB 23.9MB/s eta 0:00:01 eta 0:00:01��███████████▏              | 2.1MB 23.9MB/s eta 0:00:010:01��████████▍ | 3.6MB 53kB/s eta 0:00:04B 53kB/s eta 0:00:01
# Requirement already satisfied: absl-py>=0.7.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow>=2.0.0->turicreate) (0.7.1)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0 (from tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 37.2MB/s eta 0:00:01
# Requirement already satisfied: grpcio>=1.8.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow>=2.0.0->turicreate) (1.16.1)
# Collecting google-pasta>=0.1.6 (from tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/c3/fd/1e86bc4837cc9a3a5faf3db9b1854aa04ad35b5f381f9648fbe81a6f94e4/google_pasta-0.1.8-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 16.9MB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow>=2.0.0->turicreate) (0.33.4)
# Collecting keras-preprocessing>=1.1.0 (from tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 17.7MB/s eta 0:00:01
# Requirement already satisfied: astor>=0.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow>=2.0.0->turicreate) (0.7.1)
# Requirement already satisfied: protobuf>=3.8.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow>=2.0.0->turicreate) (3.8.0)
# Requirement already satisfied: pytz>=2011k in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.23.2->turicreate) (2019.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.23.2->turicreate) (2.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (1.25.3)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.9.1->turicreate) (3.0.4)
# Collecting numba>=0.32 (from resampy==0.2.1->turicreate)
#   Downloading https://files.pythonhosted.org/packages/8f/d7/9f0a9e1b173fddc77ad6cb8943bc433a850c2a6d3fa5c02a086400ba0c8f/numba-0.47.0-cp37-cp37m-manylinux1_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 34.1MB/s eta 0:00:01��██████████████████▉     | 3.1MB 34.1MB/s eta 0:00:01████████████████████████▎   | 3.2MB 34.1MB/s eta 0:00:01
# Requirement already satisfied: h5py in /srv/conda/envs/notebook/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow>=2.0.0->turicreate) (2.9.0)
# Requirement already satisfied: markdown>=2.6.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow>=2.0.0->turicreate) (3.1.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.2.0,>=2.1.0->tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Collecting google-auth<2,>=1.6.3 (from tensorboard<2.2.0,>=2.1.0->tensorflow>=2.0.0->turicreate)
#   Downloading https://files.pythonhosted.org/packages/1c/6d/7aae38a9022f982cf8167775c7fc299f203417b698c27080ce09060bba07/google_auth-1.11.0-py2.py3-none-any.whl (76kB)
#      |████████████████████████████████| 81kB 21.7MB/s eta 0:00:01
# Requirement already satisfied: werkzeug>=0.11.15 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow>=2.0.0->turicreate) (0.15.4)
# Requirement already satisfied: setuptools>=41.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow>=2.0.0->turicre
requests-oauthlib, google-auth-oauthlib, tensorboard, tensorflow-estimator, google-pasta, keras-preprocessing, tensorflow, prettytable, coremltools, llvmlite, numba, resampy, turicreate
#   Found existing installation: Keras-Applications 1.0.7
#     Uninstalling Keras-Applications-1.0.7:
#       Successfully uninstalled Keras-Applications-1.0.7
#   Found existing installation: tensorboard 1.13.1
#     Uninstalling tensorboard-1.13.1:
#       Successfully uninstalled tensorboard-1.13.1
#   Found existing installation: tensorflow-estimator 1.13.0
#     Uninstalling tensorflow-estimator-1.13.0:
#       Successfully uninstalled tensorflow-estimator-1.13.0
#   Found existing installation: Keras-Preprocessing 1.0.9
#     Uninstalling Keras-Preprocessing-1.0.9:
#       Successfully uninstalled Keras-Preprocessing-1.0.9
#   Found existing installation: tensorflow 1.13.1
#     Uninstalling tensorflow-1.13.1:
#       Successfully uninstalled tensorflow-1.13.1
# Successfully installed cachetools-4.0.0 coremltools-3.1 google-auth-1.11.0 google-auth-oauthlib-0.4.1 google-pasta-0.1.8 keras-applications-1.0.8 keras-preprocessing-1.1.0 llvmlite-0.31.0 numba-0.47.0 opt-einsum-3.1.0 prettytable-0.7.2 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 resampy-0.2.1 rsa-4.0 tensorboard-2.1.0 tensorflow-2.1.0 tensorflow-estimator-2.1.0 turicreate-6.0 wrapt-1.11.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import turicreate

# %% [markdown]
# # Load house sales data

# %%
sales = turicreate.SFrame('Home_data')

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# | 1954400510 | 2015-02-18 00:00:00+00:00 |  510000.0 |   3.0    |    2.0    |
# | 7237550310 | 2014-05-12 00:00:00+00:00 | 1225000.0 |   4.0    |    4.5    |
# | 1321400060 | 2014-06-27 00:00:00+00:00 |  257500.0 |   3.0    |    2.25   |
# | 2008000270 | 2015-01-15 00:00:00+00:00 |  291850.0 |   3.0    |    1.5    |
# | 2414600126 | 2015-04-15 00:00:00+00:00 |  229500.0 |   3.0    |    1.0    |
# | 3793500160 | 2015-03-12 00:00:00+00:00 |  323000.0 |   3.0    |    2.5    |
# +------------+---------------------------+-----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# +-------------+----------+--------+------------+------+-----------+-------+
# |    1180.0   |  5650.0  |  1.0   |     0      |  0   |     3     |  7.0  |
# |    2570.0   |  7242.0  |  2.0   |     0      |  0   |     3     |  7.0  |
# |    770.0    | 10000.0  |  1.0   |     0      |  0   |     3     |  6.0  |
# |    1960.0   |  5000.0  |  1.0   |     0      |  0   |     5     |  7.0  |
# |    1680.0   |  8080.0  |  1.0   |     0      |  0   |     3     |  8.0  |
# |    5420.0   | 101930.0 |  1.0   |     0      |  0   |     3     |  11.0 |
# |    1715.0   |  6819.0  |  2.0   |     0      |  0   |     3     |  7.0  |
# |    1060.0   |  9711.0  |  1.0   |     0      |  0   |     3     |  7.0  |
# |    1780.0   |  7470.0  |  1.0   |     0      |  0   |     3     |  7.0  |
# |    1890.0   |  6560.0  |  2.0   |     0      |  0   |     3     |  7.0  |
# +-------------+----------+--------+------------+------+-----------+-------+
# +------------+---------------+----------+--------------+---------+-------------+
# | sqft_above | sqft_basement | yr_built | yr_renovated | zipcode |     lat     |
# +------------+---------------+----------+--------------+---------+-------------+
# |   1180.0   |      0.0      |  1955.0  |     0.0      |  98178  | 47.51123398 |
# |   2170.0   |     400.0     |  1951.0  |    1991.0    |  98125  | 47.72102274 |
# |   770.0    |      0.0      |  1933.0  |     0.0      |  98028  | 47.73792661 |
# |   1050.0   |     910.0     |  1965.0  |     0.0      |  98136  |   47.52082  |
# |   1680.0   |      0.0      |  1987.0  |     0.0      |  98074  | 47.61681228 |
# |   3890.0   |     1530.0    |  2001.0  |     0.0      |  98053  | 47.65611835 |
# |   1715.0   |      0.0      |  1995.0  |     0.0      |  98003  | 47.30972002 |
# |   1060.0   |      0.0      |  1963.0  |     0.0      |  98198  | 47.40949984 |
# |   1050.0   |     730.0     |  1960.0  |     0.0      |  98146  | 47.51229381 |
# |   1890.0   |      0.0      |  2003.0  |     0.0      |  98038  | 47.36840673 |
# +------------+---------------+----------+--------------+---------+-------------+
# +---------------+---------------+-----+
# |      long     | sqft_living15 | ... |
# +---------------+---------------+-----+
# | -122.25677536 |     1340.0    | ... |
# |  -122.3188624 |     1690.0    | ... |
# | -122.23319601 |     2720.0    | ... |
# | -122.39318505 |     1360.0    | ... |
# | -122.04490059 |     1800.0    | ... |
# | -122.00528655 |     4760.0    | ... |
# | -122.32704857 |     2238.0    | ... |
# | -122.31457273 |     1650.0    | ... |
# | -122.33659507 |     1780.0    | ... |
# |  -122.0308176 |     2390.0    | ... |
# +---------------+---------------+-----+
# [21613 rows x 21 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# # Explore

# %%
sales.show()
# Out:
# Materializing SFrame
# Warning: Skipping column 'date'. Unable to show columns of type 'datetime'; only [int, float, str] can be shown.
# Further warnings of unsupported type will be suppressed.
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="6300" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"metadata\": {\"bubbleOpts\": {\"showAllFields\": false, \"fields\": [{\"field\": \"left\"}, {\"field\": \"right\"}, {\"field\": \"count\"}, {\"field\": \"label\"}]}}, \"width\": 800, \"height\": 6080, \"padding\": 8, \"data\": [{\"name\": \"pts_store\"}, {\"name\": \"source_2\", \"values\": [{\"a\": 0, \"title\": \"id\", \"num_row\": 21613, \"type\": \"str\", \"num_unique\": 21436, \"num_missing\": 0, \"categorical\": [{\"label\": \"0795000620\", \"label_idx\": 0, \"count\": 3, \"percentage\": \"0.0138805%\"}, {\"label\": \"0001000102\", \"label_idx\": 1, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0007200179\", \"label_idx\": 2, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0109200390\", \"label_idx\": 3, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0123039336\", \"label_idx\": 4, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0251300110\", \"label_idx\": 5, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0302000375\", \"label_idx\": 6, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0324000530\", \"label_idx\": 7, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0526059224\", \"label_idx\": 8, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"0641900050\", \"label_idx\": 9, \"count\": 2, \"percentage\": \"0.00925369%\"}, {\"label\": \"Other (21426 labels)\", \"label_idx\": 10, \"count\": 21592, \"percentage\": \"99.9028%\"}], \"numeric\": []}, {\"a\": 1, \"title\": \"price\", \"num_row\": 21613, \"type\": \"float\", \"num_unique\": 4032, \"num_missing\": 0, \"mean\": 540088.141905, \"min\": 75000.0, \"max\": 7700000.0, \"median\": 450000.0, \"stdev\": 367118.702667, \"numeric\": [{\"left\": 36033.2, \"right\": 420411, \"count\": 9578}, {\"left\": 420411, \"right\": 804788, \"count\": 9110}, {\"left\": 804788, \"right\": 1189170.0, \"count\": 1897}, {\"left\": 1189170.0, \"right\": 1573540.0, \"count\": 561}, {\"left\": 1573540.0, \"right\": 1957920.0, \"count\": 248}, {\"left\": 1957920.0, \"right\": 2342300.0, \"count\ ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales.show(view="BoxWhisker Plot",x="zipcode",y="price")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-f855126830b0> in <module>
# ----> 1 sales.show(view="BoxWhisker Plot",x="zipcode",y="price")
#
# TypeError: show() got an unexpected keyword argument 'view'

# %%
top_zip = sales[sales['zipcode']=='98039']

# %%
top_zip['price'].mean()
# Out:
# 2160606.5999999996

# %%
top_zip.show()
# Out:
# Materializing SFrame
# Warning: Skipping column 'date'. Unable to show columns of type 'datetime'; only [int, float, str] can be shown.
# Further warnings of unsupported type will be suppressed.
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="6300" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"metadata\": {\"bubbleOpts\": {\"showAllFields\": false, \"fields\": [{\"field\": \"left\"}, {\"field\": \"right\"}, {\"field\": \"count\"}, {\"field\": \"label\"}]}}, \"width\": 800, \"height\": 6080, \"padding\": 8, \"data\": [{\"name\": \"pts_store\"}, {\"name\": \"source_2\", \"values\": [{\"a\": 0, \"title\": \"id\", \"num_row\": 602, \"type\": \"str\", \"num_unique\": 600, \"num_missing\": 0, \"categorical\": [{\"label\": \"8129700644\", \"label_idx\": 0, \"count\": 2, \"percentage\": \"0.332226%\"}, {\"label\": \"9136103130\", \"label_idx\": 1, \"count\": 2, \"percentage\": \"0.332226%\"}, {\"label\": \"0091000135\", \"label_idx\": 2, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"0091000320\", \"label_idx\": 3, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"0263000006\", \"label_idx\": 4, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"0263000009\", \"label_idx\": 5, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"0263000018\", \"label_idx\": 6, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"0263000040\", \"label_idx\": 7, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"0263000050\", \"label_idx\": 8, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"0263000155\", \"label_idx\": 9, \"count\": 1, \"percentage\": \"0.166113%\"}, {\"label\": \"Other (590 labels)\", \"label_idx\": 10, \"count\": 590, \"percentage\": \"98.0066%\"}], \"numeric\": []}, {\"a\": 1, \"title\": \"price\", \"num_row\": 602, \"type\": \"float\", \"num_unique\": 356, \"num_missing\": 0, \"mean\": 584919.210963, \"min\": 238000.0, \"max\": 1695000.0, \"median\": 550000.0, \"stdev\": 208778.189182, \"numeric\": [{\"left\": 233740, \"right\": 307180, \"count\": 19}, {\"left\": 307180, \"right\": 380620, \"count\": 66}, {\"left\": 380620, \"right\": 454060, \"count\": 99}, {\"left\": 454060, \"right\": 527500, \"count\": 80}, {\"left\": 527500, \"right\": 600940, \"count\": 95}, {\"left\": 600940, \"right\": 674380, \"count\": 75}, {\"left\": 674380, \"right\": 747820, \"count\": 57 ...

# %%
sqft_liv = sales[(sales['sqft_living']>2000) & (sales['sqft_living']<=4000)]

# %%
sqft_liv.show()
# Out:
# Materializing SFrame
# Warning: Skipping column 'date'. Unable to show columns of type 'datetime'; only [int, float, str] can be shown.
# Further warnings of unsupported type will be suppressed.
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="6300" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"metadata\": {\"bubbleOpts\": {\"showAllFields\": false, \"fields\": [{\"field\": \"left\"}, {\"field\": \"right\"}, {\"field\": \"count\"}, {\"field\": \"label\"}]}}, \"width\": 800, \"height\": 6080, \"padding\": 8, \"data\": [{\"name\": \"pts_store\"}, {\"name\": \"source_2\", \"values\": [{\"a\": 0, \"title\": \"id\", \"num_row\": 9118, \"type\": \"str\", \"num_unique\": 9071, \"num_missing\": 0, \"categorical\": [{\"label\": \"0001000102\", \"label_idx\": 0, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"0251300110\", \"label_idx\": 1, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"0641900050\", \"label_idx\": 2, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"1139600270\", \"label_idx\": 3, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"1254200015\", \"label_idx\": 4, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"1568100300\", \"label_idx\": 5, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"1630700361\", \"label_idx\": 6, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"1825069031\", \"label_idx\": 7, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"1954420170\", \"label_idx\": 8, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"1974300020\", \"label_idx\": 9, \"count\": 2, \"percentage\": \"0.0219346%\"}, {\"label\": \"Other (9061 labels)\", \"label_idx\": 10, \"count\": 9098, \"percentage\": \"99.7807%\"}], \"numeric\": []}, {\"a\": 1, \"title\": \"price\", \"num_row\": 9118, \"type\": \"float\", \"num_unique\": 2417, \"num_missing\": 0, \"mean\": 653299.736565, \"min\": 194250.0, \"max\": 3100000.0, \"median\": 598555.0, \"stdev\": 312808.223041, \"numeric\": [{\"left\": 138106, \"right\": 289498, \"count\": 338}, {\"left\": 289498, \"right\": 440890, \"count\": 2028}, {\"left\": 440890, \"right\": 592282, \"count\": 2135}, {\"left\": 592282, \"right\": 743674, \"count\": 1895}, {\"left\": 743674, \"right\": 895066, \"count\": 1333}, {\"left\": 895066, \"right\": 1046460.0, \"count\": 583}, {\"left\": 1046460.0,  ...

# %%
turicreate.show(sales[1:5000]['sqft_living'],sales[1:5000]['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"autosize\": {\"type\": \"fit\", \"resize\": false, \"contains\": \"padding\"}, \"padding\": 8, \"width\": 720, \"height\": 550, \"style\": \"cell\", \"title\": \"X vs. Y\", \"data\": [{\"name\": \"source_2\", \"values\": [{\"x\": 2570.0, \"y\": 538000.0}, {\"x\": 770.0, \"y\": 180000.0}, {\"x\": 1960.0, \"y\": 604000.0}, {\"x\": 1680.0, \"y\": 510000.0}, {\"x\": 5420.0, \"y\": 1225000.0}, {\"x\": 1715.0, \"y\": 257500.0}, {\"x\": 1060.0, \"y\": 291850.0}, {\"x\": 1780.0, \"y\": 229500.0}, {\"x\": 1890.0, \"y\": 323000.0}, {\"x\": 3560.0, \"y\": 662500.0}, {\"x\": 1160.0, \"y\": 468000.0}, {\"x\": 1430.0, \"y\": 310000.0}, {\"x\": 1370.0, \"y\": 400000.0}, {\"x\": 1810.0, \"y\": 530000.0}, {\"x\": 2950.0, \"y\": 650000.0}, {\"x\": 1890.0, \"y\": 395000.0}, {\"x\": 1600.0, \"y\": 485000.0}, {\"x\": 1200.0, \"y\": 189000.0}, {\"x\": 1250.0, \"y\": 230000.0}, {\"x\": 1620.0, \"y\": 385000.0}, {\"x\": 3050.0, \"y\": 2000000.0}, {\"x\": 2270.0, \"y\": 285000.0}, {\"x\": 1070.0, \"y\": 252700.0}, {\"x\": 2450.0, \"y\": 329000.0}, {\"x\": 1710.0, \"y\": 233000.0}, {\"x\": 2450.0, \"y\": 937000.0}, {\"x\": 1400.0, \"y\": 667000.0}, {\"x\": 1520.0, \"y\": 438000.0}, {\"x\": 2570.0, \"y\": 719000.0}, {\"x\": 2320.0, \"y\": 580500.0}, {\"x\": 1190.0, \"y\": 280000.0}, {\"x\": 2330.0, \"y\": 687500.0}, {\"x\": 1090.0, \"y\": 535000.0}, {\"x\": 2060.0, \"y\": 322500.0}, {\"x\": 2300.0, \"y\": 696000.0}, {\"x\": 1660.0, \"y\": 550000.0}, {\"x\": 2360.0, \"y\": 640000.0}, {\"x\": 1220.0, \"y\": 240000.0}, {\"x\": 2620.0, \"y\": 605000.0}, {\"x\": 2570.0, \"y\": 625000.0}, {\"x\": 4220.0, \"y\": 775000.0}, {\"x\": 3595.0, \"y\": 861990.0}, {\"x\": 1570.0, \"y\": 685000.0}, {\"x\": 1280.0, \"y\": 309000.0}, {\"x\": 3160.0, \"y\": 488000.0}, {\"x\": 990.0, \"y\": 210490.0}, {\"x\": 2290.0, \"y\": 785000.0}, {\"x\": 1250.0, \"y\": 450000.0}, {\"x\": 2753.0, \"y\": 1350000.0}, {\"x\": 1190.0, \"y\": 228000.0}, {\"x\": 3150.0, \"y\": 345000.0}, {\"x\": 1410.0, \"y\": 600000.0}, {\"x\": 1980.0, \"y\": 585000.0}, {\"x\": 2730.0, \"y\": 920000.0}, {\"x\": 2830.0, \ ...

# %% [markdown]
# # Simple regression model that predicts price from square feet

# %%
training_set, test_set = sales.random_split(.8,seed=0)

# %% [markdown]
# ## train simple regression model

# %%
sqft_model = turicreate.linear_regression.create(training_set,target='price',features=['sqft_living'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | 1         | 2        | 1.024691     | 4334222.024768     | 2186797.880270       | 263182.077047                   | 258452.192694                     |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %% [markdown]
# # Evaluate the quality of our model

# %%
print (test_set['price'].mean())
# Out:
# 543054.0425632538

# %%
print (sqft_model.evaluate(test_set))
# Out:
# {'max_error': 4131524.1552114445, 'rmse': 255226.05072761464}

# %% [markdown]
# # Explore model a little further

# %%
sqft_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+---------------------+--------------------+
# |     name    | index |        value        |       stderr       |
# +-------------+-------+---------------------+--------------------+
# | (intercept) |  None | -50074.187660205294 | 5052.720482786655  |
# | sqft_living |  None |  283.4732085388029  | 2.2229117496081536 |
# +-------------+-------+---------------------+--------------------+
# [2 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(test_set['sqft_living'],test_set['price'],'.',
        test_set['sqft_living'],sqft_model.predict(test_set),'-')
# Out:
# [<matplotlib.lines.Line2D at 0x1280dc208>,
#  <matplotlib.lines.Line2D at 0x1280dc4a8>]

# %% [markdown]
# # Explore other features of the data

# %%
my_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','zipcode']

# %%
sales[my_features].show()
# Out:
# Materializing SFrame
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="2100" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/3.0.8/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/3.0.0-rc7/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"metadata\": {\"bubbleOpts\": {\"showAllFields\": false, \"fields\": [{\"field\": \"left\"}, {\"field\": \"right\"}, {\"field\": \"count\"}, {\"field\": \"label\"}]}}, \"width\": 800, \"height\": 1880, \"padding\": 0, \"data\": [{\"name\": \"pts_store\"}, {\"name\": \"source_2\", \"values\": [{\"a\": 0, \"title\": \"bedrooms\", \"num_row\": 21613, \"type\": \"str\", \"num_unique\": 13, \"num_missing\": 0, \"categorical\": [{\"label\": \"3\", \"label_idx\": 0, \"count\": 9824, \"percentage\": \"45.4541%\"}, {\"label\": \"4\", \"label_idx\": 1, \"count\": 6882, \"percentage\": \"31.8419%\"}, {\"label\": \"2\", \"label_idx\": 2, \"count\": 2760, \"percentage\": \"12.7701%\"}, {\"label\": \"5\", \"label_idx\": 3, \"count\": 1601, \"percentage\": \"7.40758%\"}, {\"label\": \"6\", \"label_idx\": 4, \"count\": 272, \"percentage\": \"1.2585%\"}, {\"label\": \"1\", \"label_idx\": 5, \"count\": 199, \"percentage\": \"0.920742%\"}, {\"label\": \"7\", \"label_idx\": 6, \"count\": 38, \"percentage\": \"0.17582%\"}, {\"label\": \"0\", \"label_idx\": 7, \"count\": 13, \"percentage\": \"0.060149%\"}, {\"label\": \"8\", \"label_idx\": 8, \"count\": 13, \"percentage\": \"0.060149%\"}, {\"label\": \"9\", \"label_idx\": 9, \"count\": 6, \"percentage\": \"0.0277611%\"}], \"numeric\": []}, {\"a\": 1, \"title\": \"bathrooms\", \"num_row\": 21613, \"type\": \"str\", \"num_unique\": 30, \"num_missing\": 0, \"categorical\": [{\"label\": \"2.5\", \"label_idx\": 0, \"count\": 5380, \"percentage\": \"24.8924%\"}, {\"label\": \"1\", \"label_idx\": 1, \"count\": 3852, \"percentage\": \"17.8226%\"}, {\"label\": \"1.75\", \"label_idx\": 2, \"count\": 3048, \"percentage\": \"14.1026%\"}, {\"label\": \"2.25\", \"label_idx\": 3, \"count\": 2047, \"percentage\": \"9.47115%\"}, {\"label\": \"2\", \"label_idx\": 4, \"count\": 1930, \"percentage\": \"8.92981%\"}, {\"label\": \"1.5\", \"label_idx\": 5, \"count\": 1446, \"percentage\": \"6.69042%\"}, {\"label\": \"2.75\", \"label_idx\": 6, \"count\": 1185, \"percentage\": \"5.48281%\"}, {\"label\": \"3\", \"label_idx\": 7, \"c ...

# %%
turicreate.show(sales['zipcode'],sales['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# <html>                 <body>                     <iframe style="border:0;margin:0" width="800" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/3.0.8/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/3.0.0-rc7/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"autosize\": \"fit\", \"metadata\": {\"bubbleOpts\": {\"showAllFields\": false, \"fields\": [{\"field\": \"x\"}, {\"field\": \"min\"}, {\"field\": \"lower quartile\"}, {\"field\": \"median\"}, {\"field\": \"upper quartile\"}, {\"field\": \"max\"}]}}, \"title\": {\"text\": \"X vs Y\", \"offset\": 30}, \"padding\": 5, \"height\": 550, \"style\": \"cell\", \"data\": [{\"name\": \"source_2\", \"values\": [{\"x\": \"98188\", \"min\": 110000, \"lower quartile\": 230000, \"median\": 265000, \"upper quartile\": 335000, \"max\": 707000}, {\"x\": \"98155\", \"min\": 153000, \"lower quartile\": 315000, \"median\": 375000, \"upper quartile\": 460000, \"max\": 4500000.0}, {\"x\": \"98168\", \"min\": 78000, \"lower quartile\": 199950, \"median\": 235000, \"upper quartile\": 285000, \"max\": 600000}, {\"x\": \"98058\", \"min\": 95000, \"lower quartile\": 285000, \"median\": 335000, \"upper quartile\": 392000, \"max\": 1500000.0}, {\"x\": \"98045\", \"min\": 175000, \"lower quartile\": 305000, \"median\": 399500, \"upper quartile\": 495000, \"max\": 1950000.0}, {\"x\": \"98055\", \"min\": 100000, \"lower quartile\": 240000, \"median\": 295000, \"upper quartile\": 350000, \"max\": 631000}, {\"x\": \"98148\", \"min\": 105500, \"lower quartile\": 240000, \"median\": 278000, \"upper quartile\": 319990, \"max\": 600600}, {\"x\": \"98106\", \"min\": 90000, \"lower quartile\": 260000, \"median\": 315000, \"upper quartile\": 366000, \"max\": 795000}, {\"x\": \"98024\", \"min\": 142000, \"lower quartile\": 340000, \"median\": 460000, \"upper quartile\": 700000, \"max\": 1862000.0}, {\"x\": \"98011\", \"min\": 245500, \"lower quartile\": 411800, \"median\": 470000, \"upper quartile\": 550000, \"max\": 1075000.0}, {\"x\": \"98039\", \"min\": 787500, \"lower quartile\": 1398000.0, \"median\": 1905000.0, \"upper quartile\": 2575000.0, \"max\": 6885000.0}, {\"x\": \"98031\", \"min\": 147500, \"lower quartile\": 252000, \"median\": 288400, \"upper quartile\": 327500, \"max\": 800000}, {\"x\": \"98014\", \"min\": 80000, \"lower quartile\": 309000, \"median\": 415000, \ ...

# %% [markdown]
# # Build a model with these additional features

# %%
my_features_model = turicreate.linear_regression.create(training_set,target='price',features=my_features,validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 75
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 1.669837     | 4086543.315840     | 189216.804808                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %% [markdown]
# # Compare simple model with more complex one

# %%
print (my_features)
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
print (sqft_model.evaluate(test_set))
print (my_features_model.evaluate(test_set))
# Out:
# {'max_error': 4136882.6348793716, 'rmse': 255209.21881082928}
# {'max_error': 3539726.837428363, 'rmse': 179363.49443647868}

# %% [markdown]
# # Apply learned models to make predictions

# %%
house1 = sales[sales['id']=='5309101200']

# %%
house1
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+--------+----------+-----------+-------------+
# |     id     |            date           | price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+--------+----------+-----------+-------------+
# | 5309101200 | 2014-06-05 00:00:00+00:00 | 620000 |    4     |    2.25   |     2400    |
# +------------+---------------------------+--------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |   5350   |  1.5   |     0      |  0   |     4     |   7   |    1460    |      940      |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# | yr_built | yr_renovated | zipcode |     lat     |      long     | sqft_living15 | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# |   1929   |      0       |  98117  | 47.67632376 | -122.37010126 |     1250.0    | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# [? rows x 21 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %% [markdown]
# <img src="http://blue.kingcounty.com/Assessor/eRealProperty/MediaHandler.aspx?Media=2916871">

# %%
print (house1['price'])
# Out:
# [620000, ... ]

# %%
print (sqft_model.predict(house1))
# Out:
# [629976.0401234042]

# %%
print (my_features_model.predict(house1))
# Out:
# [724495.9972504767]

# %% [markdown]
# ## Prediction for a second house, a fancier one

# %%
house2 = sales[sales['id']=='1925069082']

# %%
house2
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 1925069082 | 2015-05-11 00:00:00+00:00 | 2200000 |    5     |    4.25   |     4640    |
# +------------+---------------------------+---------+----------+-----------+-------------+
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# | sqft_lot | floors | waterfront | view | condition | grade | sqft_above | sqft_basement |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# |  22703   |   2    |     1      |  4   |     5     |   8   |    2860    |      1780     |
# +----------+--------+------------+------+-----------+-------+------------+---------------+
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# | yr_built | yr_renovated | zipcode |     lat     |      long     | sqft_living15 | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# |   1952   |      0       |  98052  | 47.63925783 | -122.09722322 |     3140.0    | ... |
# +----------+--------------+---------+-------------+---------------+---------------+-----+
# [? rows x 21 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %% [markdown]
# <img src="https://ssl.cdn-redfin.com/photo/1/bigphoto/302/734302_0.jpg">

# %%
print (sqft_model.predict(house2))
# Out:
# [1263438.8662907984]

# %%
print (my_features_model.predict(house2))
# Out:
# [1442070.3235753486]

# %% [markdown]
# ## Prediction for a super fancy home

# %%
bill_gates = {'bedrooms':[8], 
              'bathrooms':[25], 
              'sqft_living':[50000], 
              'sqft_lot':[225000],
              'floors':[4], 
              'zipcode':['98039'], 
              'condition':[10], 
              'grade':[10],
              'waterfront':[1],
              'view':[4],
              'sqft_above':[37500],
              'sqft_basement':[12500],
              'yr_built':[1994],
              'yr_renovated':[2010],
              'lat':[47.627606],
              'long':[-122.242054],
              'sqft_living15':[5000],
              'sqft_lot15':[40000]}

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/26/Residence_of_Bill_Gates.jpg">

# %%
print (my_features_model.predict(turicreate.SFrame(bill_gates)))
# Out:
# [13491984.465966508]

# %%
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition',
'grade',
'waterfront',
'view',
'sqft_above',
'sqft_basement',
'yr_built',
'yr_renovated',
'lat', 'long',
'sqft_living15',
'sqft_lot15',
]

# %%
saad_test = turicreate.linear_regression.create(training_set,target='price',features=advanced_features,validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 18
# Number of unpacked features : 18
# Number of coefficients    : 87
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 0.870266     | 4336058.938761     | 162392.982702                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
print (saad_test.evaluate(test_set))
print (my_features_model.evaluate(test_set))
# Out:
# {'max_error': 3170363.1813852815, 'rmse': 155269.65792807922}
# {'max_error': 3152242.7848689146, 'rmse': 180439.07296640845}
